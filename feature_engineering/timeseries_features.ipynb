# %%
from visualisation import visualise_features, visualise_dataset
from features import load_dataframe, performance

# %%
# Restart the kernel if needed
# import os
# os._exit(00)

# %% [markdown]
# ### Visualise our data

# %%
# Get our dataframe
df = load_dataframe()
visualise_dataset(df)
# Out:
# /mnt/c/Users/Tom/Documents/ML/ML_main_project/Data2017/preprocessed

# %% [markdown]
# ### Base Features

# %%
# Base features performance, where we use K Nearest Neighbors.
# Here is our baseline, now we add features.
performance(df)
visualise_features(["dayOfWeek", "month", "time"], df, "Base Features")
# Out:
# /mnt/c/Users/Tom/Documents/ML/ML_main_project/Data2017/preprocessed
# Base MSE is: 532.94498

# %%
df
# Out:
#                      dayOfWeek  month  time  volume
# datetime
# 2017-01-01 00:00:00          7      1     0     451
# 2017-01-01 01:00:00          7      1   100     652
# 2017-01-01 02:00:00          7      1   200     527
# 2017-01-01 03:00:00          7      1   300     462
# 2017-01-01 04:00:00          7      1   400     514
# ...                        ...    ...   ...     ...
# 2017-01-31 19:00:00          2      1  1900    3273
# 2017-01-31 20:00:00          2      1  2000    2110
# 2017-01-31 21:00:00          2      1  2100    1593
# 2017-01-31 22:00:00          2      1  2200    1307
# 2017-01-31 23:00:00          2      1  2300     667
#
# [744 rows x 4 columns]

# %% [markdown]
# ### Extra Features

# %%
df["quarter"] = df.index.quarter
df["weekOfYear"] = df.index.weekofyear
df["dayOfYear"] = df.index.dayofyear
# Out:
# /tmp/ipykernel_1774/1340504958.py:2: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   df["weekOfYear"] = df.index.weekofyear

# %%
visualise_features(["quarter", "weekOfYear", "dayOfYear"], df, "Additional Features")
performance(df)
# Out:
# Base MSE is: 708.62807

# %% [markdown]
# ### Review:
# Looks like our base features do best.
# Newer features perform quite poorly, though this could be because we have such a small dataset right now.

# %%
# Get our dataframe back to original features by running cell towards top
df
# Out:
#                      dayOfWeek  month  time  volume
# datetime
# 2017-01-01 00:00:00          7      1     0     451
# 2017-01-01 01:00:00          7      1   100     652
# 2017-01-01 02:00:00          7      1   200     527
# 2017-01-01 03:00:00          7      1   300     462
# 2017-01-01 04:00:00          7      1   400     514
# ...                        ...    ...   ...     ...
# 2017-01-31 19:00:00          2      1  1900    3273
# 2017-01-31 20:00:00          2      1  2000    2110
# 2017-01-31 21:00:00          2      1  2100    1593
# 2017-01-31 22:00:00          2      1  2200    1307
# 2017-01-31 23:00:00          2      1  2300     667
#
# [744 rows x 4 columns]
